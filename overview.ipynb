# %% [markdown]
# # Homographies in the Real World

# %% [markdown]
# We want to answer the following Questions about Homographies in the Real World:

# %% [markdown]
# 1. **How good is a homography in real world conditions?**
# 2. **How much do point compositions influence results?**
# 3. **How much influence do perspectives have?**

# %% [markdown]
# ## 1. How good is a homography in real world conditions?

# %% [markdown]
# **Assumptions:**
# - Planar Scene
# - Three of four points not collinear (Homography Degeneracy)

# %% [markdown]
# To answer this question, we took images from various perspectives and with various reference / validation point settings. The error varies depending on perspective and point compositions, however, for reasonable settings, the approach is good.

# %% [markdown]
# ![image.png](attachment:f2a0e7af-0a89-4bdd-8cd9-424ae82892f7.png)

# %% [markdown]
# ## 2. How much do point compositions influence the results? OR: Is it robust?????

# %% [markdown]
# 1. How many points should be used, and does it matter? (NOISE EXPERIMENT WITH ONLY FOUR POINTS, AS IT WILL BE MORE PRONE TO NOISE.)
# 2. How should we spread points?
# 3. How robust is the approach to measurement noise?
# 4. How robust is the approach to outliers?
# 5. What does it mean that three of four points are collinear in the real world? They certaintly won't be!

# %% [markdown]
# ### 2.1 How Many Points should be used, does it matter?

# %% [markdown]
# So a homography uses optimization algorithms like **least squares** or **RANSAC**. Hence, we won't use all points. Four points are theoretically enough, but it is not recommended to use only four. Why? Noise. **SVD**?

# %% [markdown]
# To answer this question, we can use all possible reference point compositions and have a look. Over all images. GOOD BAD? IDK MAN.

# %% [markdown]
# What we did but with all images actually. Same results that 4 best, but more better. Why? Maybe because you avaerage the plane ground better.

# %% [markdown]
# ![image.png](attachment:26215f7b-eee4-497c-a0e0-cff2e0970f03.png)

# %% [markdown]
# TODO: For each image?

# %% [markdown]
# **Conclusion:** Four points are enough. But the composition matters a lot. How to spread the points?!

# %% [markdown]
# **Actually, I think you should use every point available. And use RANSAC**

# %% [markdown]
# ### 2.2 How To spread points?

# %% [markdown]
# **Hypothesis:** It does not matter. However, if you span a big area, the large plane averages over the planar violations, which leads to better results.

# %% [markdown]
# As we use some markings that are really markant, is this really that important? We have to use what we can, so we cannot be 100% free. However, which markings to choose?

# %% [markdown]
# ## 2.3. How Robust are point compositions

# %% [markdown]
# Try some outliers, try some noise spread across all points. It should be RANSAC > Least squares. Quantify the robustness.

# %% [markdown]
# #### 2.3.1 Outliers

# %% [markdown]
# Results.

# %% [markdown]
# #### 2.3.2 Noise

# %% [markdown]
# Resuts

# %% [markdown]
# ## 3. How does perspective influence the approach?

# %% [markdown]
# Points w.r.t. pixel density.

# %% [markdown]
# # 4. Automate it

# %% [markdown]
# Use Road segmentation on FoV in Top View and on Perspective View. Make mask and try SIFT. Let's see how it works.

# %% [markdown]
# Insert an Image here.
